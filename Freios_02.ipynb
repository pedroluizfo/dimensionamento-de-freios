# %%
#importando bibliotecas.
import pandas as pd
import math as m
import os
#verificando e criando a pasta "pasta".
if os.path.exists('./pasta'):
    print('Já existe')
else: 
    os.mkdir('./pasta')

#desingn do dataframe
Df = pd.DataFrame(columns=['Distância','Tempo','Pressão Cil. Mestre [Pa]','Coeficiente de atrito','Area da Pastilha Furada [m²]','Raio do furo (mm)','Aceleração','Força Pinça [N]','Força Fricção [N]' ,'Torque de frenagem [N/m]','Area Max Furada [m²]', 'Num. furos','ForcaCaliperF',])
#criando repetição das entradas.
c = ''
while c != 'N':  

    vf = 19.44
    vi = 22.22
    massa = 850
    RaioEf = (99.875)/1000
    AreaCaliper = float(706.86)*(10**(-6)) #não condiz com a realidade (5mm de raio)
    AreaPastilha = float(3521.856)*(10**(-6)) #não condiz com a realidade eu acho
    RaioRoda = 0.1155
    
    d = float(input('Distância [m]: '))
    print(f'Distância: {d} m')
    aceleração = (((vf*2)-(vi*2))/(2*d))
    print(f'Aceleração: {(aceleração * -1):.4f} m/s²')
    tempo = vi/(aceleração*-1)
    print(f'Tempo: {tempo:.4f} s')
    
    ForcaTotal = massa * aceleração
    TorqueTotal = (ForcaTotal/4) * RaioRoda
    
    Pressure = float(input('Pressão Cilindro Mestre [Pa]: '))
    print(f'Pressão do cilindro mestre: {Pressure:.4f} Pa')

    ForcaCaliper = 2*((Pressure*AreaCaliper)/AreaPastilha)
    print(f'Força Pinça: {ForcaCaliper:.4f} N')

    mi = float(input('Coeficiente de atrito: '))
    ForcaFriccao = ForcaCaliper*mi
    print(f'Força Fricção: {ForcaFriccao:.4f} N')

    TorqueFrenagem = ForcaFriccao*RaioEf
    print(f'Torque de frenagem: {TorqueFrenagem:.4f} N/m')

    if ForcaTotal > ForcaCaliper:
        print('Refazer parametros, Força insuficiente para frenagem')
    else: 
        print('Força suficientes para frenagem')
    
    if TorqueTotal > TorqueFrenagem:
        print('Refazer parametros, Torque insuficiente para frenagem')
    else: 
        print('Torque suficientes para frenagem')

    AreaPastilhaF = float(input('Nova Area da Pastilha Furada [m²]: '))
    print(f'Nova Area da pastilha furada: {AreaPastilhaF:.5f} m²')
    AreaMaximaFurada = AreaPastilha-AreaPastilhaF
    print(f'Area Máxima que pode ser furada [m²]: {AreaMaximaFurada:.6f}')

    RaioFuro = float(input('Raio do furo [mm]: ')) 
    NumFuros = AreaMaximaFurada//(m.pi*((RaioFuro/1000)**2))
    print(f'Numero de furos que podem ser feitos: {NumFuros:.4f}') 
   
    ForcaCaliperF =  2*((Pressure*AreaCaliper)/AreaPastilhaF)
    ForcaFriccaoF = ForcaCaliperF*mi  
    TorqueFrenagemF = ForcaFriccaoF*RaioEf

    print(f'Nova Força caliper {ForcaCaliperF:.4f} N')
    print(f'Nova Força friccção {ForcaFriccaoF:.4f} N')
    print(f'Nova Torque frenagem {TorqueFrenagemF:.4f} N/m')
    
    if ForcaTotal > ForcaCaliperF:
        print('Refazer parametros, nova força insuficiente para frenagem')
    else: 
        print('Nova força suficiente para frenagem')
    
    if TorqueTotal > TorqueFrenagemF:
        print('Refazer parametros, novo torque insuficiente para frenagem')
    else: 
        print('Novo torque suficiente para frenagem')

 
    
    
    
    c = str(input('Continuar? ')).capitalize()
    Df = Df.append(pd.Series( {'Distância [m]':d,'Tempo [s]':tempo,'Pressão Cil. Mestre [Pa]': Pressure ,'Coeficiente de atrito': mi,'Area da Pastilha Furada [m²]': AreaPastilhaF ,'Raio do furo (mm)': RaioFuro,'Aceleração [m/s²] ':aceleração ,'Força Pinça [N]': ForcaCaliper,'Força Fricção [N]': ForcaFriccao,'Torque de frenagem [N/m]':TorqueFrenagem,'Area Max Furada [m²]': AreaMaximaFurada, 'Num. furos': NumFuros,'ForcaCaliperF [N]':ForcaCaliperF,'ForcaFriccaoF [N]':ForcaFriccaoF,'TorqueFrenagemF [N/m]':TorqueFrenagemF}), ignore_index=True)
print(Df)
continuar = str(input('Deseja salvar o arquivo? [S] ou [N] ')).capitalize()
if continuar == 'S':
    pasta='./pasta'
    cont = 1
    for diretorio, subpastas, arquivos in os.walk(pasta):
        for arquivo in arquivos:
            cont = cont+1
            print(os.path.join(diretorio, arquivo))
            print(cont)
    writer = pd.ExcelWriter(f'./pasta/Dados de frenagem teste {cont}.xlsx')
    Df.to_excel(writer)
    writer.save()
    print("DataFrame is exported successfully to 'Dados de frenagem teste' Excel File.")

    df_novo= pd.read_excel(f'pasta\dados de frenagem teste {cont}.xlsx')
else:
    print('O programa foi encerrado sem salvar os dados!')
# Out:
# Já existe
# Distância: 5.0 m
# Aceleração: 0.5560 m/s²
# Tempo: 39.9640 s
# Pressão do cilindro mestre: 30000.0000 Pa
# Força Pinça: 12042.4004 N
# Força Fricção: 3612.7201 N
# Torque de frenagem: 360.8204 N/m
# Força suficientes para frenagem
# Torque suficientes para frenagem
# Área da pastilha furada: 0.00200 m²
# Area Máxima que pode ser furada [m²]: 0.001522
# Numero de furos que podem ser feitos: 53.0000
# Nova Força caliper 21205.8000 N
# Nova Força friccção 6361.7400 N
# Nova Torque frenagem 635.3788 N/m
# Nova força suficiente para frenagem
# Novo torque suficiente para frenagem
# C:\Users\Casa\AppData\Local\Temp\ipykernel_13232\3038656124.py:90: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Df = Df.append(pd.Series( {'Distância':d,'Tempo':tempo,'Pressão Cil. Mestre [Pa]': Pressure ,'Coeficiente de atrito': mi,'Area da Pastilha Furada [m²]': AreaPastilhaF ,'Raio do furo (mm)': RaioFuro,'Aceleração':aceleração ,'Força Pinça [N]': ForcaCaliper,'Força Fricção [N]': ForcaFriccao,'Torque de frenagem [N/m]':TorqueFrenagem,'Area Max Furada [m²]': AreaMaximaFurada, 'Num. furos': NumFuros,'ForcaCaliperF':ForcaCaliperF,'ForcaFriccaoF':ForcaFriccaoF,'TorqueFrenagemF':TorqueFrenagemF}), ignore_index=True)
# Distância: 10.0 m
# Aceleração: 0.2780 m/s²
# Tempo: 79.9281 s
# Pressão do cilindro mestre: 35000.0000 Pa
# Força Pinça: 14049.4671 N
# Força Fricção: 4917.3135 N
# Torque de frenagem: 491.1167 N/m
# Força suficientes para frenagem
# Torque suficientes para frenagem
# Área da pastilha furada: 0.00300 m²
# Area Máxima que pode ser furada [m²]: 0.000522
# Numero de furos que podem ser feitos: 6.0000
# Nova Força caliper 16493.4000 N
# Nova Força friccção 5772.6900 N
# Nova Torque frenagem 576.5474 N/m
# Nova força suficiente para frenagem
# Novo torque suficiente para frenagem
# C:\Users\Casa\AppData\Local\Temp\ipykernel_13232\3038656124.py:90: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Df = Df.append(pd.Series( {'Distância':d,'Tempo':tempo,'Pressão Cil. Mestre [Pa]': Pressure ,'Coeficiente de atrito': mi,'Area da Pastilha Furada [m²]': AreaPastilhaF ,'Raio do furo (mm)': RaioFuro,'Aceleração':aceleração ,'Força Pinça [N]': ForcaCaliper,'Força Fricção [N]': ForcaFriccao,'Torque de frenagem [N/m]':TorqueFrenagem,'Area Max Furada [m²]': AreaMaximaFurada, 'Num. furos': NumFuros,'ForcaCaliperF':ForcaCaliperF,'ForcaFriccaoF':ForcaFriccaoF,'TorqueFrenagemF':TorqueFrenagemF}), ignore_index=True)
# Distância: 15.0 m
# Aceleração: 0.1853 m/s²
# Tempo: 119.8921 s
# Pressão do cilindro mestre: 20000.0000 Pa
# Força Pinça: 8028.2669 N
# Força Fricção: 2007.0667 N
# Torque de frenagem: 200.4558 N/m
# Força suficientes para frenagem
# Torque suficientes para frenagem
# Área da pastilha furada: 0.00300 m²
# Area Máxima que pode ser furada [m²]: 0.000522
# Numero de furos que podem ser feitos: 3.0000
# Nova Força caliper 9424.8000 N
# Nova Força friccção 2356.2000 N
# Nova Torque frenagem 235.3255 N/m
# Nova força suficiente para frenagem
# Novo torque suficiente para frenagem
# C:\Users\Casa\AppData\Local\Temp\ipykernel_13232\3038656124.py:90: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Df = Df.append(pd.Series( {'Distância':d,'Tempo':tempo,'Pressão Cil. Mestre [Pa]': Pressure ,'Coeficiente de atrito': mi,'Area da Pastilha Furada [m²]': AreaPastilhaF ,'Raio do furo (mm)': RaioFuro,'Aceleração':aceleração ,'Força Pinça [N]': ForcaCaliper,'Força Fricção [N]': ForcaFriccao,'Torque de frenagem [N/m]':TorqueFrenagem,'Area Max Furada [m²]': AreaMaximaFurada, 'Num. furos': NumFuros,'ForcaCaliperF':ForcaCaliperF,'ForcaFriccaoF':ForcaFriccaoF,'TorqueFrenagemF':TorqueFrenagemF}), ignore_index=True)
#    Distância       Tempo  Pressão Cil. Mestre [Pa]  Coeficiente de atrito  \
# 0        5.0   39.964029                   30000.0                   0.30
# 1       10.0   79.928058                   35000.0                   0.35
# 2       15.0  119.892086                   20000.0                   0.25
#
#    Area da Pastilha Furada [m²]  Raio do furo (mm)  Aceleração  \
# 0                         0.002                3.0   -0.556000
# 1                         0.003                5.0   -0.278000
# 2                         0.003                7.0   -0.185333
#
#    Força Pinça [N]  Força Fricção [N]  Torque de frenagem [N/m]  \
# 0     12042.400371        3612.720111                360.820421
# 1     14049.467099        4917.313485                491.116684
# 2      8028.266914        2007.066728                200.455790
#
#    Area Max Furada [m²]  Num. furos  ForcaCaliperF  ForcaFriccaoF  \
# 0              0.001522        53.0        21205.8        6361.74
# 1              0.000522         6.0        16493.4        5772.69
# 2              0.000522         3.0         9424.8        2356.20
#
#    TorqueFrenagemF
# 0       635.378783
# 1       576.547414
# 2       235.325475
# DataFrame is exported successfully to 'Dados de frenagem teste' Excel File.
# C:\Users\Casa\AppData\Local\Temp\ipykernel_13232\3038656124.py:103: FutureWarning: save is not part of the public API, usage can give unexpected results and will be removed in a future version
#   writer.save()
